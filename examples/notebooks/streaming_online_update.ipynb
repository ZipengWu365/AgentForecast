# %% [markdown]
# # Streaming / online update
# Use a streaming backend over a bundled monitoring series.

# %%
from agentforecast import forecast_stream_csv
from agentforecast.datasets import dataset_path

# %%
result = forecast_stream_csv(dataset_path('icu-bed-stress'), backend='stream_ewm', outdir='demo_stream')
result.summary

# %%
result.diagnostics['streaming']
