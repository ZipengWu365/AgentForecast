# %% [markdown]
# # Hosted gallery
# Generate demo runs and then build a static gallery site.

# %%
from agentforecast.cli import _demo_gallery

# %%
manifest = _demo_gallery('demo_gallery_runs', 'public_gallery/site')
manifest

# %%
from pathlib import Path
Path('public_gallery/site/index.html').resolve()
