# %% [markdown]
# # Backend arena
# Compare several backends on one bundled dataset.

# %%
from agentforecast import compare_backends_dataset

# %%
arena = compare_backends_dataset('gold', backends=['naive', 'stats_arima', 'ml_ridge', 'stream_ewm'], outdir='demo_arena')
arena.summary

# %%
arena.leaderboard
