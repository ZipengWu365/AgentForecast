# %% [markdown]
# # ICU bed stress watch
#
# Generate a compact hospital-pressure pack and inspect streaming diagnostics.

# %%
from agentforecast import run_case

# %%
result = run_case('icu-bed-stress-watch', outdir='demo')

# %%
result.diagnostics['streaming']

# %%
result.artifacts
