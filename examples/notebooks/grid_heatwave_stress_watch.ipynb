# %% [markdown]
# # Grid heatwave stress watch

# %%
from agentforecast import run_case
result = run_case("grid-heatwave-stress-watch", outdir="grid_demo")
result.summary

# %% [markdown]
# This is the pattern for public-utility or infrastructure stress monitoring.

# %%
result.artifacts
