# %% [markdown]
# # Outpatient no-show watch

# %%
from agentforecast import run_case
result = run_case("outpatient-no-show-watch", outdir="clinic_demo")
result.summary

# %% [markdown]
# Operational healthcare series often benefit from fast artifact generation more than deep estimator complexity.

# %%
result.metrics
