# %% [markdown]
# # Compare methods on one series
#
# Compare classical, tabular, and streaming backends on the same time series.

# %%
from agentforecast import compare_backends_dataset

# %%
arena = compare_backends_dataset('gold', backends=['naive','stats_arima','ml_ridge','river_snarimax'], outdir='demo')

# %%
arena.backend_selected

# %%
arena.leaderboard

# %%
arena.artifacts
