# %% [markdown]
# # Beamline drift watch
#
# Use a streaming backend to monitor instrument drift and produce a forecast card.

# %%
from agentforecast import run_case

# %%
result = run_case('beamline-drift-watch', outdir='demo')

# %%
result.metrics

# %%
result.diagnostics['streaming']

# %%
result.artifacts
