# %% [markdown]
# # Messy CSV cleanup
#
# This notebook shows the cleanup path for duplicates, missing timestamps, and interpolation.

# %%
import pandas as pd

# %%
from agentforecast.features import prepare_series_frame

# %%
frame = pd.read_csv('messy_series.csv')

# %%
prepared = prepare_series_frame(frame)

# %%
prepared.cleanup
