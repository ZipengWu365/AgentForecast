# %% [markdown]
# # River flood risk watch

# %%
from agentforecast import run_case
result = run_case("river-flood-risk-watch", outdir="river_demo")
result.summary

# %% [markdown]
# Use this pattern when updates arrive continuously and drift-aware behavior matters.

# %%
result.diagnostics
