# %% [markdown]
# # URL to pack
#
# Use a CSV URL and turn it into a chart, card, markdown report, and JSON result.

# %%
from agentforecast import forecast_url

# %%
result = forecast_url('file:///tmp/my_series.csv', outdir='demo')

# %%
result.summary

# %%
result.metrics

# %%
result.artifacts
