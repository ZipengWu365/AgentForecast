# %% [markdown]
# # Air quality smoke watch
#
# Generate a public-risk brief from an AQI-like series.

# %%
from agentforecast import run_case

# %%
result = run_case('air-quality-smoke-watch', outdir='demo')

# %%
result.summary

# %%
result.artifacts
