# %% [markdown]
# # Forecast your CSV
#
# Bring a two-column CSV into agentforecast and export a pack.

# %% [markdown]
# Install the lean path or an editable local build first.

# %%
from agentforecast import forecast_csv

# %%
result = forecast_csv('my_series.csv', outdir='demo')

# %%
result.summary

# %%
result.artifacts
