# %% [markdown]
# # Gold price with exogenous CSV
#
# Use bundled exogenous columns such as DXY-, VIX-, and yield-like signals.

# %%
from agentforecast import write_dataset
path = write_dataset("gold-exogenous", "tmp_data")
path

# %% [markdown]
# The CSV includes `ds`, `y`, and exogenous columns. `agentforecast` will automatically pick them up as feature candidates.

# %%
from agentforecast import forecast_csv
result = forecast_csv(path, backend="auto", strategy="accurate", outdir="demo_exog")
result.summary

# %% [markdown]
# Inspect the produced artifacts: chart, leaderboard, markdown report, and JSON metadata.

# %%
result.artifacts[:3]
