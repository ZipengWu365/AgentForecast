# %% [markdown]
# # When Ridge beats Transformer
#
# A conceptual notebook about why simple models can win once data size, latency, and robustness matter.

# %% [markdown]
# This project does **not** assume deep backends are always best. Many short or medium series are won by Ridge, ETS, or ARIMA-style models.

# %%
from agentforecast import compare_backends_dataset
result = compare_backends_dataset("gold", backends=["naive", "stats_arima", "ml_ridge", "stream_ewm"], outdir="ridge_vs_heavy")
result.summary

# %% [markdown]
# In real deployments, the right question is often: which model family wins **after** you price in install friction, calibration, and maintainability?

# %%
result.leaderboard
